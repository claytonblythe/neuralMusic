# %%
import torch 
import torch.nn as nn
import torchvision.datasets as dsets
import torchvision.transforms as transforms
from torch.autograd import Variable
import librosa
import librosa.display
import torchaudio
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
y, sr = librosa.load('/Users/claytonblythe/Desktop/RAM/lose_yourself_to_dance.mp3', mono=True,  sr=None)

# %%
song_duration = librosa.core.get_duration(y, sr)
print(song_duration)
random_offset = random.uniform(0,song_duration)
print(random_offset)
# Out:
# 356.55156462585035
# 226.85048165477878

# %%
y, sr = librosa.load('/Users/claytonblythe/Desktop/RAM/lose_yourself_to_dance.mp3', mono=True,  offset=random_offset, duration= 5.94, sr=None)

# %%
y.shape, sr
# Out:
# ((261954,), 44100)

# %%
librosa.core.get_duration(y, sr)
# Out:
# 5.94

# %%
S = librosa.feature.melspectrogram(y=y, n_mels=128, fmax=8000)
plt.figure(figsize=(10,4))
librosa.display.specshow(librosa.power_to_db(S, ref=np.max), 
                        y_axis='mel', fmax=8000, 
                        x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Mel spectrogram')
plt.tight_layout()
plt.show()
S.shape
# Out:
# (128, 512)

# %%
S = librosa.feature.melspectrogram(y=y, n_mels=128*2, fmax=8000)
plt.figure(figsize=(10,4))
librosa.display.specshow(librosa.power_to_db(S, ref=np.max), 
                        y_axis='mel', fmax=8000, 
                        x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Mel spectrogram')
plt.tight_layout()
plt.show()
S.shape
# Out:
# (256, 512)

# %%
S = librosa.feature.melspectrogram(y=y, n_mels=128*4, fmax=8000)
plt.figure(figsize=(10,4))
librosa.display.specshow(librosa.power_to_db(S, ref=np.max), 
                        y_axis='mel', fmax=8000, 
                        x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Mel spectrogram')
plt.tight_layout()
plt.show()
S.shape
# Out:
# (512, 512)
