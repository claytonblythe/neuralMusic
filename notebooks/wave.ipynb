# %%
import torch 
import torch.nn as nn
import torchvision.datasets as dsets
import torchvision.transforms as transforms
from torch.autograd import Variable
import librosa
import librosa.display
import torchaudio
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
sound, sr = torchaudio.load('../data/wave.mp3')

# %%
sound.size()
# Out:
# torch.Size([1997568, 2])

# %%
sound
# Out:
#  0.0000e+00  0.0000e+00
#  0.0000e+00  0.0000e+00
#  0.0000e+00  0.0000e+00
#            ⋮
#  0.0000e+00  0.0000e+00
#  0.0000e+00  0.0000e+00
#  0.0000e+00  0.0000e+00
# [torch.FloatTensor of size 1997568x2]

# %%
sound[:,1]
# Out:
#  0.0000e+00
#  0.0000e+00
#  0.0000e+00
#      ⋮
#  0.0000e+00
#  0.0000e+00
#  0.0000e+00
# [torch.FloatTensor of size 1997568]

# %%
differences = sound[:,0] != sound[:,1]

# %%
differences.sum()
# Out:
# 0

# %%
sound = sound[:,0]

# %%
sound.size()
# Out:
# torch.Size([1997568])

# %%
sound.numpy()
# Out:
# array([ 0.,  0.,  0., ...,  0.,  0.,  0.], dtype=float32)

# %%
D = librosa.core.stft(sound.numpy(), n_fft=2048)

# %%
D.shape
# Out:
# (1025, 3902)

# %%
librosa.display.specshow(librosa.amplitude_to_db(D, ref=np.max), y_axis='log', x_axis='time')

# %%
plt.title('Power spectrogram')
plt.colorbar(format='%+2.0f dB')
plt.tight_layout()
plt.show()
